# %% [markdown]
# # Analysis of the rent dataset

# %% [markdown]
# ## Overview
#
# Before we start analyzing the data and explaining our intentions, we need to get an overview of the existing data. No matter what we later want to do, we have to clean and prepocess our data in order to work with it

# %% [markdown]
# ### Load data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pandas.api.types import is_object_dtype
pd.set_option('display.max_columns', None)
# %matplotlib inline
from scipy.stats import linregress

# %%
df = pd.read_csv("../data/testlizenz-tuebingen-dataliteracy4students_1706088512814.csv", sep=";", encoding='unicode_escape')
df.count()
# Out:
# angebot_id                    106720
# anz_parken                     50795
# anz_zimmer                    106517
# aus_alarmanlage_janein        106720
# aus_bad_dusche_janein         106720
#                                ...
# oeig_dachgeschoss_janein      106720
# enddate                       105945
# aus_balkon_terrasse_janein    106720
# aus_wintergarten_janein       106720
# aus_garten_eigen_janein       106720
# Length: 86, dtype: int64

# %%
# include year column
df['year'] = df['startdate'].str[:4] 
df['endyear'] = df['enddate'].str[:4] 
df["month"] = pd.DatetimeIndex(df['startdate']).month

# %% [markdown]
# # For linear regression, filter for Tübingen

# %%
df["oadr_ort"].unique()
# Out:
# array(['Stuttgart', 'Tübingen', 'Reutlingen'], dtype=object)

# %%
df = df[df["oadr_ort"] == "Tübingen"]
df.shape
# Out:
# (9935, 89)

# %%
oadr_u2 = df["oadr_u2"].unique().tolist()
cleaned_oadr_2 = [x for x in oadr_u2 if x == x]
cleaned_oadr_2
# Out:
# ['Zentrum',
#  'Unterjesingen',
#  'Bühl',
#  'Universität',
#  'Wanne',
#  'Weilheim',
#  'De-Zentrum',
#  'Schönblick/Waldhäuser Ost',
#  'Weststadt',
#  'Österberg/Gartenstraße',
#  'Bebenhausen',
#  'Denzenberg/Sand',
#  'Pfrondorf',
#  'Südstadt',
#  'Hagelloch',
#  'Au/Unterer Wert/Französiches Viertel',
#  'Feuerhägle/Mühlenviertel',
#  'Lustnau-Zentrum/Herrlesberg/Stäudach',
#  'Hirschau',
#  'Kilchberg',
#  'Neuhalde',
#  'Aeule',
#  'Gartenstadt']

# %% [markdown]
# For the further approach, knowing where the houses are is important. Therefore we will now clean the data and remove all entries that do not have a location attribute.

# %%
df_w_loc = df[df['oadr_u2'].notna()]
df_wo_loc = df[df['oadr_u2'].isna()]
print(f"Total number of rows with location: {df_w_loc.shape[0]}")
print(f"Total number of rows without location: {df_wo_loc.shape[0]}")
# Out:
# Total number of rows with location: 6300
# Total number of rows without location: 3635

# %% [markdown]
# ### Adjusting entries
# From previous analysis I know that the integer and float values in the dataset are kind of messy, pandas cant interpret them as actual values because they are seperated with **`,`** instead of **`.`** Lets fix this.

# %%
df_w_loc
# Out:
#         angebot_id  anz_parken anz_zimmer  aus_alarmanlage_janein  \
# 25      3600015008         NaN         2,                       0
# 81      3599773217         1.0         4,                       0
# 86      3599734940         1.0         3,                       0
# 87      3599732598         1.0         2,                       0
# 94      3599699094         NaN         2,                       0
# ...            ...         ...        ...                     ...
# 106630  1401425145         1.0         3,                       0
# 106639   747572580         1.0         2,                       0
# 106694    60855988         NaN         2,                       0
# 106705    27424499         1.0         2,                       0
# 106718  3040210896         NaN         4,                       0
#
#         aus_bad_dusche_janein  aus_bad_gaestewc_janein  \
# 25                          1                        0
# 81                          1                        1
# 86                          1                        0
# 87                          0                        0
# 94                          0                        0
# ...                       ...                      ...
# 106630                      0                        0
# 106639                      0                        0
# 106694                      1                        0
# 106705                      1                        0
# 106718                      0                        1
#
#         aus_bad_mit_fenster_janein  aus_bad_wanne_janein  \
# 25                               1                     0
# 81                               0                     0
# 86                               1                     1
# 87                               0                     0
# 94                               0                     0
# ...                            ...                   ...
# 106630                           0                     0
# 106639                           0                     0
# 106694                           0                     0
# 106705                           0                     1
# 106718                           0                     1
#
#         aus_heiz_alt_erdw_janein  aus_heiz_alt_solar_janein  \
# 25                             0                          0
# 81                             0                          0
# 86                             0                          0
# 87                             0                          0
# 94                             0                          0
# ...                          ...                        ...
# 106630                         0                          0
# 106639                         0                          0
# 106694                         0                          0
# 106705                         0                          0
# 106718                         0                          0
#
#         aus_heiz_alt_pellet_janein  aus_heiz_alt_pumpe_janein  \
# 25                               0                          0
# 81                               0                          0
# 86                               0                          0
# 87                               0                          0
# 94                               0                          0
# ...                            ...                        ...
# 106630                           0                          0
# 106639                           0                          0
# 106694                           0                          0
# 106705                           0                          0
# 106718                           0                          0
#
#         aus_heiz_blockkw_janein aus_heiz_befeuerung  \
# 25                            0                 Gas
# 81                            0                 Gas
# 86                            0                 Gas
# 87                            0             Elektro
# 94                            0                 NaN
# ...                         ...                 ...
# 106630                        0                 Gas
# 106639                        0                 NaN
# 106694                        0             Elektro
# 106705                        0             Elektro
# 106718                        0                  Öl
#
#         aus_heiz_fernwaerme_janein  aus_heiz_fussboden_janein  \
# 25                               0                          0
# 81                               0                          0
# 86                               0                          1
# 87                               0                          0
# 94                               1                          0
# ...                            ...                        ...
# 106630                           0                          0
# 106639                           0                          0
# 106694                           0                          0
# 106705                           0                          0
# 106718                           0                          0
#
#         aus_heiz_keine_janein aus_heiz_system  aus_kamin_janein  \
# 25                          0             NaN                 0
# 81                          0         Zentral                 0
# 86                          0             NaN                 0
# 87                          0          Zimmer                 0
# 94                          0         Zentral                 0
# ...                       ...             ...               ...
# 106630                      0         Zentral                 0
# 106639                      0             NaN                 0
# 106694                      0             NaN                 0
# 106705                      0           Etage                 0
# 106718                      0         Zentral                 0
#
#         aus_kueche_einbau_janein  aus_kueche_offen_janein  \
# 25                             1                        1
# 81                             1                        0
# 86                             1                        0
# 87                             0                        0
# 94                             1                        0
# ...                          ...                      ...
# 106630                         1                        0
# 106639                         1                        0
# 106694                         1                        0
# 106705                         1                        0
# 106718                         1                        0
#
#         aus_kueche_pantry_janein  aus_lift_janein  aus_moebliert_janein  \
# 25                             0                0                     0
# 81                             0                0                     0
# 86                             0                1                     0
# 87                             0                0                     0
# 94                             0                0                     0
# ...                          ...              ...                   ...
# 106630                         0                0                     0
# 106639                         0                0                     0
# 106694                         0                0                     0
# 106705                         0                0                     0
# 106718                         0                0                     0
#
#         aus_parken_carport_janein  aus_parken_janein  \
# 25                              0                  0
# 81                              0                  1
# 86                              0                  1
# 87                              0                  1
# 94                              0                  0
# ...                           ...                ...
# 106630                          0                  1
# 106639                          0                  1
# 106694                          0                  0
# 106705                          0                  1
# 106718                          0                  0
#
#         aus_parken_ladestation_janein  aus_parken_stellplaetze_janein  \
# 25                                  0                               0
# 81                                  0                               1
# 86                                  0                               0
# 87                                  0                               0
# 94                                  0                               0
# ...                               ...                             ...
# 106630                              0                               0
# 106639                              0                               0
# 106694                              0                               0
# 106705                              0                               0
# 106718                              0                               0
#
#         aus_pool_janein  aus_sauna_janein  baujahr flaeche etage etagen  \
# 25                    0                 0   1980.0     58,    2,     3,
# 81                    0                 0   1970.0     85,    0,     3,
# 86                    0                 0   2013.0   70,78    1,     2,
# 87                    0                 0   2023.0     22,    2,    NaN
# 94                    0                 0      NaN     56,   -,5     3,
# ...                 ...               ...      ...     ...   ...    ...
# 106630                0                 0      NaN     93,   NaN    NaN
# 106639                0                 0      NaN     90,   NaN    NaN
# 106694                0                 0   1957.0     48,   NaN    NaN
# 106705                0                 0      NaN    77,1   NaN    NaN
# 106718                0                 0      NaN     87,    0,    NaN
#
#        fl_wohnen kosten kosten_je_flaeche  kosten_miete_gesamt_janein  \
# 25           58,   870,               15,                           0
# 81           85,  1100,             12,94                           0
# 86         70,78   980,             13,85                           0
# 87           22,   550,               25,                           0
# 94           56,   750,             13,39                           0
# ...          ...    ...               ...                         ...
# 106630       93,   980,             10,54                           0
# 106639       90,   770,              8,56                           0
# 106694       48,   420,              8,75                           0
# 106705      77,1   650,              8,43                           0
# 106718       87,   630,              7,24                           0
#
#         kstn_betriebskosten  kstn_betriebskosten_pqm kstn_heizung  \
# 25                      NaN                      NaN         170,
# 81                      NaN                      NaN         280,
# 86                      NaN                      NaN          NaN
# 87                      NaN                      NaN          NaN
# 94                      NaN                      NaN          NaN
# ...                     ...                      ...          ...
# 106630                  NaN                      NaN          NaN
# 106639                  NaN                      NaN          NaN
# 106694                  NaN                      NaN          NaN
# 106705                  NaN                      NaN          NaN
# 106718                  NaN                      NaN          NaN
#
#        laufzeitw_alle laufzeitw_geschl nachfrageart nutzungsart  oadr_bl  \
# 25                 ,2              NaN        miete        Wohn        8
# 81                 ,5              NaN        miete        Wohn        8
# 86                 ,3               ,3        miete        Wohn        8
# 87                 ,1               ,1        miete        Wohn        8
# 94                 ,6              NaN        miete        Wohn        8
# ...               ...              ...          ...         ...      ...
# 106630           19,4             19,4        miete        Wohn        8
# 106639           23,1             23,1        miete        Wohn        8
# 106694           31,7             31,7        miete        Wohn        8
# 106705           38,1             38,1        miete        Wohn        8
# 106718          186,9            186,9        miete        Wohn        8
#
#         oadr_gkz  oadr_kkz kstn_nebenkosten kstn_miete_kalt kstn_miete_gesamt  \
# 25       8416041      8416             170,            870,             1040,
# 81       8416041      8416              70,           1100,             1450,
# 86       8416041      8416             290,            980,             1270,
# 87       8416041      8416              50,            550,              600,
# 94       8416041      8416             150,            750,              900,
# ...          ...       ...              ...             ...               ...
# 106630   8416041      8416             140,            980,             1120,
# 106639   8416041      8416             170,            770,              940,
# 106694   8416041      8416              50,            420,              470,
# 106705   8416041      8416             130,            650,              780,
# 106718   8416041      8416             150,            630,              780,
#
#        kstn_miete_gesamt_pqm kstn_miete_kalt_pqm  kstn_kaufpreis  \
# 25                     17,93                 15,             NaN
# 81                     17,06               12,94             NaN
# 86                     17,94               13,85             NaN
# 87                     27,27                 25,             NaN
# 94                     16,07               13,39             NaN
# ...                      ...                 ...             ...
# 106630                 12,04               10,54             NaN
# 106639                 10,44                8,56             NaN
# 106694                  9,79                8,75             NaN
# 106705                 10,12                8,43             NaN
# 106718                  8,97                7,24             NaN
#
#         kstn_kaufpreis_pqm kstn_heizung_pqm oadr_kreis  oadr_ort  oadr_plz  \
# 25                     NaN             2,93   Tübingen  Tübingen     72070
# 81                     NaN             3,29   Tübingen  Tübingen     72070
# 86                     NaN              NaN   Tübingen  Tübingen     72072
# 87                     NaN              NaN   Tübingen  Tübingen     72074
# 94                     NaN              NaN   Tübingen  Tübingen     72076
# ...                    ...              ...        ...       ...       ...
# 106630                 NaN              NaN   Tübingen  Tübingen     72072
# 106639                 NaN              NaN   Tübingen  Tübingen     72076
# 106694                 NaN              NaN   Tübingen  Tübingen     72074
# 106705                 NaN              NaN   Tübingen  Tübingen     72070
# 106718                 NaN              NaN   Tübingen  Tübingen     72070
#
#               oadr_u1                   oadr_u2 objektart objekttyp  \
# 25           Tübingen                   Zentrum   Einheit   Wohnung
# 81      Unterjesingen             Unterjesingen   Einheit   Wohnung
# 86               Bühl                      Bühl   Einheit   Wohnung
# 87           Tübingen               Universität   Einheit   Wohnung
# 94           Tübingen                     Wanne   Einheit   Wohnung
# ...               ...                       ...       ...       ...
# 106630    Derendingen  Feuerhägle/Mühlenviertel   Einheit   Wohnung
# 106639       Tübingen                     Wanne   Einheit   Wohnung
# 106694       Tübingen               Universität   Einheit   Wohnung
# 106705       Tübingen                 Weststadt   Einheit   Wohnung
# 106718  Unterjesingen             Unterjesingen   Einheit   Wohnung
#
#        objekttyp_fein objekttyp_grob  oeig_altbau_janein  zust_saniert_janein  \
# 25            2-Z-Whg        Wohnung                   0                    0
# 81            4-Z-Whg        Wohnung                   0                    1
# 86            3-Z-Whg        Wohnung                   0                    0
# 87            2-Z-Whg        Wohnung                   0                    0
# 94            2-Z-Whg        Wohnung                   0                    1
# ...               ...            ...                 ...                  ...
# 106630        3-Z-Whg        Wohnung                   0                    1
# 106639        2-Z-Whg        Wohnung                   0                    0
# 106694        2-Z-Whg        Wohnung                   0                    0
# 106705        2-Z-Whg        Wohnung                   0                    0
# 106718        4-Z-Whg        Wohnung                   0                    0
#
#         zust_neuwertig_janein  zust_projektiert_janein  \
# 25                          1                        0
# 81                          0                        0
# 86                          1                        0
# 87                          0                        0
# 94                          0                        0
# ...                       ...                      ...
# 106630                      0                        0
# 106639                      0                        0
# 106694                      0                        0
# 106705                      0                        0
# 106718                      0                        0
#
#         zust_modernisierungsjahr  zust_gepflegt_janein   startdate segment  \
# 25                           NaN                     0  2023-12-30   WHG_M
# 81                           NaN                     0  2023-12-28   WHG_M
# 86                           NaN                     0  2023-12-27   WHG_M
# 87                           NaN                     0  2023-12-27   WHG_M
# 94                        2023.0                     0  2023-12-27   WHG_M
# ...                          ...                   ...         ...     ...
# 106630                       NaN                     0  2011-10-31   WHG_M
# 106639                       NaN                     0  2011-10-04   WHG_M
# 106694                       NaN                     0  2011-08-02   WHG_M
# 106705                    2011.0                     0  2011-07-23   WHG_M
# 106718                       NaN                     0  2010-10-15   WHG_M
#
#         oeig_wbs_janein  oeig_vermietet_janein  oeig_reihenendhaus_janein3  \
# 25                    0                      0                           0
# 81                    0                      0                           0
# 86                    0                      0                           0
# 87                    0                      0                           0
# 94                    0                      0                           0
# ...                 ...                    ...                         ...
# 106630                0                      0                           0
# 106639                0                      0                           0
# 106694                0                      0                           0
# 106705                0                      0                           0
# 106718                0                      0                           0
#
#         oeig_neubau_janein  oeig_loggia_janein  oeig_keller_janein  \
# 25                       0                   0                   1
# 81                       0                   0                   1
# 86                       0                   0                   1
# 87                       1                   0                   0
# 94                       0                   0                   1
# ...                    ...                 ...                 ...
# 106630                   0                   0                   1
# 106639                   0                   0                   0
# 106694                   0                   0                   1
# 106705                   0                   0                   1
# 106718                   0                   0                   1
#
#         oeig_freistehend_janein  oeig_denkmal_janein  \
# 25                            0                    0
# 81                            0                    0
# 86                            0                   -1
# 87                            0                   -1
# 94                            0                    0
# ...                         ...                  ...
# 106630                        0                    0
# 106639                        0                    0
# 106694                        0                    0
# 106705                        0                    0
# 106718                        0                    0
#
#         oeig_dachgeschoss_janein     enddate  aus_balkon_terrasse_janein  \
# 25                             1  2024-01-02                           0
# 81                            -1         NaN                           1
# 86                             0  2023-12-29                           1
# 87                             0  2023-12-28                           0
# 94                            -1  2024-01-04                           1
# ...                          ...         ...                         ...
# 106630                         0  2012-03-15                           0
# 106639                         0  2012-03-14                           0
# 106694                         0  2012-03-11                           1
# 106705                         0  2012-04-15                           1
# 106718                        -1  2014-05-15                           1
#
#         aus_wintergarten_janein  aus_garten_eigen_janein  year endyear  month
# 25                            0                        0  2023    2024     12
# 81                            0                       -1  2023     NaN     12
# 86                            0                       -1  2023    2023     12
# 87                            0                        0  2023    2023     12
# 94                            0                        0  2023    2024     12
# ...                         ...                      ...   ...     ...    ...
# 106630                        0                        0  2011    2012     10
# 106639                        0                        0  2011    2012     10
# 106694                        0                        0  2011    2012      8
# 106705                        0                        0  2011    2012      7
# 106718                        0                        0  2010    2014     10
#
# [6300 rows x 89 columns]

# %%
for column in df.columns:
    if is_object_dtype(df[column]):
        if df[column].str.contains(',').any(): 
            df[column] = df[column].str.replace(',', '.').astype(float)
            df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
df_w_loc
# Out:
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/1307623920.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc[column] = df_w_loc[column].str.replace(',', '.').astype(float)
#         angebot_id  anz_parken  anz_zimmer  aus_alarmanlage_janein  \
# 25      3600015008         NaN         2.0                       0
# 81      3599773217         1.0         4.0                       0
# 86      3599734940         1.0         3.0                       0
# 87      3599732598         1.0         2.0                       0
# 94      3599699094         NaN         2.0                       0
# ...            ...         ...         ...                     ...
# 106630  1401425145         1.0         3.0                       0
# 106639   747572580         1.0         2.0                       0
# 106694    60855988         NaN         2.0                       0
# 106705    27424499         1.0         2.0                       0
# 106718  3040210896         NaN         4.0                       0
#
#         aus_bad_dusche_janein  aus_bad_gaestewc_janein  \
# 25                          1                        0
# 81                          1                        1
# 86                          1                        0
# 87                          0                        0
# 94                          0                        0
# ...                       ...                      ...
# 106630                      0                        0
# 106639                      0                        0
# 106694                      1                        0
# 106705                      1                        0
# 106718                      0                        1
#
#         aus_bad_mit_fenster_janein  aus_bad_wanne_janein  \
# 25                               1                     0
# 81                               0                     0
# 86                               1                     1
# 87                               0                     0
# 94                               0                     0
# ...                            ...                   ...
# 106630                           0                     0
# 106639                           0                     0
# 106694                           0                     0
# 106705                           0                     1
# 106718                           0                     1
#
#         aus_heiz_alt_erdw_janein  aus_heiz_alt_solar_janein  \
# 25                             0                          0
# 81                             0                          0
# 86                             0                          0
# 87                             0                          0
# 94                             0                          0
# ...                          ...                        ...
# 106630                         0                          0
# 106639                         0                          0
# 106694                         0                          0
# 106705                         0                          0
# 106718                         0                          0
#
#         aus_heiz_alt_pellet_janein  aus_heiz_alt_pumpe_janein  \
# 25                               0                          0
# 81                               0                          0
# 86                               0                          0
# 87                               0                          0
# 94                               0                          0
# ...                            ...                        ...
# 106630                           0                          0
# 106639                           0                          0
# 106694                           0                          0
# 106705                           0                          0
# 106718                           0                          0
#
#         aus_heiz_blockkw_janein aus_heiz_befeuerung  \
# 25                            0                 Gas
# 81                            0                 Gas
# 86                            0                 Gas
# 87                            0             Elektro
# 94                            0                 NaN
# ...                         ...                 ...
# 106630                        0                 Gas
# 106639                        0                 NaN
# 106694                        0             Elektro
# 106705                        0             Elektro
# 106718                        0                  Öl
#
#         aus_heiz_fernwaerme_janein  aus_heiz_fussboden_janein  \
# 25                               0                          0
# 81                               0                          0
# 86                               0                          1
# 87                               0                          0
# 94                               1                          0
# ...                            ...                        ...
# 106630                           0                          0
# 106639                           0                          0
# 106694                           0                          0
# 106705                           0                          0
# 106718                           0                          0
#
#         aus_heiz_keine_janein aus_heiz_system  aus_kamin_janein  \
# 25                          0             NaN                 0
# 81                          0         Zentral                 0
# 86                          0             NaN                 0
# 87                          0          Zimmer                 0
# 94                          0         Zentral                 0
# ...                       ...             ...               ...
# 106630                      0         Zentral                 0
# 106639                      0             NaN                 0
# 106694                      0             NaN                 0
# 106705                      0           Etage                 0
# 106718                      0         Zentral                 0
#
#         aus_kueche_einbau_janein  aus_kueche_offen_janein  \
# 25                             1                        1
# 81                             1                        0
# 86                             1                        0
# 87                             0                        0
# 94                             1                        0
# ...                          ...                      ...
# 106630                         1                        0
# 106639                         1                        0
# 106694                         1                        0
# 106705                         1                        0
# 106718                         1                        0
#
#         aus_kueche_pantry_janein  aus_lift_janein  aus_moebliert_janein  \
# 25                             0                0                     0
# 81                             0                0                     0
# 86                             0                1                     0
# 87                             0                0                     0
# 94                             0                0                     0
# ...                          ...              ...                   ...
# 106630                         0                0                     0
# 106639                         0                0                     0
# 106694                         0                0                     0
# 106705                         0                0                     0
# 106718                         0                0                     0
#
#         aus_parken_carport_janein  aus_parken_janein  \
# 25                              0                  0
# 81                              0                  1
# 86                              0                  1
# 87                              0                  1
# 94                              0                  0
# ...                           ...                ...
# 106630                          0                  1
# 106639                          0                  1
# 106694                          0                  0
# 106705                          0                  1
# 106718                          0                  0
#
#         aus_parken_ladestation_janein  aus_parken_stellplaetze_janein  \
# 25                                  0                               0
# 81                                  0                               1
# 86                                  0                               0
# 87                                  0                               0
# 94                                  0                               0
# ...                               ...                             ...
# 106630                              0                               0
# 106639                              0                               0
# 106694                              0                               0
# 106705                              0                               0
# 106718                              0                               0
#
#         aus_pool_janein  aus_sauna_janein  baujahr  flaeche  etage  etagen  \
# 25                    0                 0   1980.0    58.00    2.0     3.0
# 81                    0                 0   1970.0    85.00    0.0     3.0
# 86                    0                 0   2013.0    70.78    1.0     2.0
# 87                    0                 0   2023.0    22.00    2.0     NaN
# 94                    0                 0      NaN    56.00   -0.5     3.0
# ...                 ...               ...      ...      ...    ...     ...
# 106630                0                 0      NaN    93.00    NaN     NaN
# 106639                0                 0      NaN    90.00    NaN     NaN
# 106694                0                 0   1957.0    48.00    NaN     NaN
# 106705                0                 0      NaN    77.10    NaN     NaN
# 106718                0                 0      NaN    87.00    0.0     NaN
#
#         fl_wohnen  kosten  kosten_je_flaeche  kosten_miete_gesamt_janein  \
# 25          58.00   870.0              15.00                           0
# 81          85.00  1100.0              12.94                           0
# 86          70.78   980.0              13.85                           0
# 87          22.00   550.0              25.00                           0
# 94          56.00   750.0              13.39                           0
# ...           ...     ...                ...                         ...
# 106630      93.00   980.0              10.54                           0
# 106639      90.00   770.0               8.56                           0
# 106694      48.00   420.0               8.75                           0
# 106705      77.10   650.0               8.43                           0
# 106718      87.00   630.0               7.24                           0
#
#         kstn_betriebskosten  kstn_betriebskosten_pqm  kstn_heizung  \
# 25                      NaN                      NaN         170.0
# 81                      NaN                      NaN         280.0
# 86                      NaN                      NaN           NaN
# 87                      NaN                      NaN           NaN
# 94                      NaN                      NaN           NaN
# ...                     ...                      ...           ...
# 106630                  NaN                      NaN           NaN
# 106639                  NaN                      NaN           NaN
# 106694                  NaN                      NaN           NaN
# 106705                  NaN                      NaN           NaN
# 106718                  NaN                      NaN           NaN
#
#         laufzeitw_alle  laufzeitw_geschl nachfrageart nutzungsart  oadr_bl  \
# 25                 0.2               NaN        miete        Wohn        8
# 81                 0.5               NaN        miete        Wohn        8
# 86                 0.3               0.3        miete        Wohn        8
# 87                 0.1               0.1        miete        Wohn        8
# 94                 0.6               NaN        miete        Wohn        8
# ...                ...               ...          ...         ...      ...
# 106630            19.4              19.4        miete        Wohn        8
# 106639            23.1              23.1        miete        Wohn        8
# 106694            31.7              31.7        miete        Wohn        8
# 106705            38.1              38.1        miete        Wohn        8
# 106718           186.9             186.9        miete        Wohn        8
#
#         oadr_gkz  oadr_kkz  kstn_nebenkosten  kstn_miete_kalt  \
# 25       8416041      8416             170.0            870.0
# 81       8416041      8416              70.0           1100.0
# 86       8416041      8416             290.0            980.0
# 87       8416041      8416              50.0            550.0
# 94       8416041      8416             150.0            750.0
# ...          ...       ...               ...              ...
# 106630   8416041      8416             140.0            980.0
# 106639   8416041      8416             170.0            770.0
# 106694   8416041      8416              50.0            420.0
# 106705   8416041      8416             130.0            650.0
# 106718   8416041      8416             150.0            630.0
#
#         kstn_miete_gesamt  kstn_miete_gesamt_pqm  kstn_miete_kalt_pqm  \
# 25                 1040.0                  17.93                15.00
# 81                 1450.0                  17.06                12.94
# 86                 1270.0                  17.94                13.85
# 87                  600.0                  27.27                25.00
# 94                  900.0                  16.07                13.39
# ...                   ...                    ...                  ...
# 106630             1120.0                  12.04                10.54
# 106639              940.0                  10.44                 8.56
# 106694              470.0                   9.79                 8.75
# 106705              780.0                  10.12                 8.43
# 106718              780.0                   8.97                 7.24
#
#         kstn_kaufpreis  kstn_kaufpreis_pqm  kstn_heizung_pqm oadr_kreis  \
# 25                 NaN                 NaN              2.93   Tübingen
# 81                 NaN                 NaN              3.29   Tübingen
# 86                 NaN                 NaN               NaN   Tübingen
# 87                 NaN                 NaN               NaN   Tübingen
# 94                 NaN                 NaN               NaN   Tübingen
# ...                ...                 ...               ...        ...
# 106630             NaN                 NaN               NaN   Tübingen
# 106639             NaN                 NaN               NaN   Tübingen
# 106694             NaN                 NaN               NaN   Tübingen
# 106705             NaN                 NaN               NaN   Tübingen
# 106718             NaN                 NaN               NaN   Tübingen
#
#         oadr_ort  oadr_plz        oadr_u1                   oadr_u2 objektart  \
# 25      Tübingen     72070       Tübingen                   Zentrum   Einheit
# 81      Tübingen     72070  Unterjesingen             Unterjesingen   Einheit
# 86      Tübingen     72072           Bühl                      Bühl   Einheit
# 87      Tübingen     72074       Tübingen               Universität   Einheit
# 94      Tübingen     72076       Tübingen                     Wanne   Einheit
# ...          ...       ...            ...                       ...       ...
# 106630  Tübingen     72072    Derendingen  Feuerhägle/Mühlenviertel   Einheit
# 106639  Tübingen     72076       Tübingen                     Wanne   Einheit
# 106694  Tübingen     72074       Tübingen               Universität   Einheit
# 106705  Tübingen     72070       Tübingen                 Weststadt   Einheit
# 106718  Tübingen     72070  Unterjesingen             Unterjesingen   Einheit
#
#        objekttyp objekttyp_fein objekttyp_grob  oeig_altbau_janein  \
# 25       Wohnung        2-Z-Whg        Wohnung                   0
# 81       Wohnung        4-Z-Whg        Wohnung                   0
# 86       Wohnung        3-Z-Whg        Wohnung                   0
# 87       Wohnung        2-Z-Whg        Wohnung                   0
# 94       Wohnung        2-Z-Whg        Wohnung                   0
# ...          ...            ...            ...                 ...
# 106630   Wohnung        3-Z-Whg        Wohnung                   0
# 106639   Wohnung        2-Z-Whg        Wohnung                   0
# 106694   Wohnung        2-Z-Whg        Wohnung                   0
# 106705   Wohnung        2-Z-Whg        Wohnung                   0
# 106718   Wohnung        4-Z-Whg        Wohnung                   0
#
#         zust_saniert_janein  zust_neuwertig_janein  zust_projektiert_janein  \
# 25                        0                      1                        0
# 81                        1                      0                        0
# 86                        0                      1                        0
# 87                        0                      0                        0
# 94                        1                      0                        0
# ...                     ...                    ...                      ...
# 106630                    1                      0                        0
# 106639                    0                      0                        0
# 106694                    0                      0                        0
# 106705                    0                      0                        0
# 106718                    0                      0                        0
#
#         zust_modernisierungsjahr  zust_gepflegt_janein   startdate segment  \
# 25                           NaN                     0  2023-12-30   WHG_M
# 81                           NaN                     0  2023-12-28   WHG_M
# 86                           NaN                     0  2023-12-27   WHG_M
# 87                           NaN                     0  2023-12-27   WHG_M
# 94                        2023.0                     0  2023-12-27   WHG_M
# ...                          ...                   ...         ...     ...
# 106630                       NaN                     0  2011-10-31   WHG_M
# 106639                       NaN                     0  2011-10-04   WHG_M
# 106694                       NaN                     0  2011-08-02   WHG_M
# 106705                    2011.0                     0  2011-07-23   WHG_M
# 106718                       NaN                     0  2010-10-15   WHG_M
#
#         oeig_wbs_janein  oeig_vermietet_janein  oeig_reihenendhaus_janein3  \
# 25                    0                      0                           0
# 81                    0                      0                           0
# 86                    0                      0                           0
# 87                    0                      0                           0
# 94                    0                      0                           0
# ...                 ...                    ...                         ...
# 106630                0                      0                           0
# 106639                0                      0                           0
# 106694                0                      0                           0
# 106705                0                      0                           0
# 106718                0                      0                           0
#
#         oeig_neubau_janein  oeig_loggia_janein  oeig_keller_janein  \
# 25                       0                   0                   1
# 81                       0                   0                   1
# 86                       0                   0                   1
# 87                       1                   0                   0
# 94                       0                   0                   1
# ...                    ...                 ...                 ...
# 106630                   0                   0                   1
# 106639                   0                   0                   0
# 106694                   0                   0                   1
# 106705                   0                   0                   1
# 106718                   0                   0                   1
#
#         oeig_freistehend_janein  oeig_denkmal_janein  \
# 25                            0                    0
# 81                            0                    0
# 86                            0                   -1
# 87                            0                   -1
# 94                            0                    0
# ...                         ...                  ...
# 106630                        0                    0
# 106639                        0                    0
# 106694                        0                    0
# 106705                        0                    0
# 106718                        0                    0
#
#         oeig_dachgeschoss_janein     enddate  aus_balkon_terrasse_janein  \
# 25                             1  2024-01-02                           0
# 81                            -1         NaN                           1
# 86                             0  2023-12-29                           1
# 87                             0  2023-12-28                           0
# 94                            -1  2024-01-04                           1
# ...                          ...         ...                         ...
# 106630                         0  2012-03-15                           0
# 106639                         0  2012-03-14                           0
# 106694                         0  2012-03-11                           1
# 106705                         0  2012-04-15                           1
# 106718                        -1  2014-05-15                           1
#
#         aus_wintergarten_janein  aus_garten_eigen_janein  year endyear  month
# 25                            0                        0  2023    2024     12
# 81                            0                       -1  2023     NaN     12
# 86                            0                       -1  2023    2023     12
# 87                            0                        0  2023    2023     12
# 94                            0                        0  2023    2024     12
# ...                         ...                      ...   ...     ...    ...
# 106630                        0                        0  2011    2012     10
# 106639                        0                        0  2011    2012     10
# 106694                        0                        0  2011    2012      8
# 106705                        0                        0  2011    2012      7
# 106718                        0                        0  2010    2014     10
#
# [6300 rows x 89 columns]

# %%
df_w_loc.shape[0]
# Out:
# 6300

# %% [markdown]
# # Scatter plot und lineare Regression
#
# Falls der approach nicht gut aussieht, müssen wir vielleicht auf polynomial regression umsteigen

# %%
interesting_regions = df_w_loc["oadr_u2"].unique().tolist()
interesting_regions = [x for x in interesting_regions if x == x]

# %%
df_w_loc["endyear"].isna().sum()
# Out:
# 18

# %% [markdown]
# ## Führ das unten aus wenn du enddate als variable willst, aber uns fehlen da 18 werte, deswegen droppen

# %%
# df_w_loc= df_w_loc[df["endyear"].notna()]
# df_w_loc = df_w_loc.dropna(subset=["year"])
# df_w_loc["year"]= df_w_loc["endyear"]

# %% [markdown]
# ### Lass das aber mal auskommentiert pls

# %%
df_w_loc["year"].isna().sum()
# Out:
# 0

# %%
df_w_loc['year_month'] = df_w_loc['year'].astype(str) + '-' + df_w_loc['month'].astype(str).str.zfill(2)
df_w_loc = df_w_loc.sort_values(by=['year_month'])
df_w_loc
# Out:
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/103856554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_w_loc['year_month'] = df_w_loc['year'].astype(str) + '-' + df_w_loc['month'].astype(str).str.zfill(2)
#         angebot_id  anz_parken  anz_zimmer  aus_alarmanlage_janein  \
# 106718  3040210896         NaN         4.0                       0
# 106705    27424499         1.0         2.0                       0
# 106694    60855988         NaN         2.0                       0
# 106639   747572580         1.0         2.0                       0
# 106630  1401425145         1.0         3.0                       0
# ...            ...         ...         ...                     ...
# 463     3597737629         NaN         2.5                       0
# 440     3597845360         1.0         5.0                       0
# 428     3598461421         NaN         3.0                       0
# 593     3597146913         1.0         2.5                       0
# 25      3600015008         NaN         2.0                       0
#
#         aus_bad_dusche_janein  aus_bad_gaestewc_janein  \
# 106718                      0                        1
# 106705                      1                        0
# 106694                      1                        0
# 106639                      0                        0
# 106630                      0                        0
# ...                       ...                      ...
# 463                         0                        0
# 440                         1                        1
# 428                         1                        0
# 593                         1                        0
# 25                          1                        0
#
#         aus_bad_mit_fenster_janein  aus_bad_wanne_janein  \
# 106718                           0                     1
# 106705                           0                     1
# 106694                           0                     0
# 106639                           0                     0
# 106630                           0                     0
# ...                            ...                   ...
# 463                              0                     0
# 440                              0                     1
# 428                              0                     0
# 593                              1                     0
# 25                               1                     0
#
#         aus_heiz_alt_erdw_janein  aus_heiz_alt_solar_janein  \
# 106718                         0                          0
# 106705                         0                          0
# 106694                         0                          0
# 106639                         0                          0
# 106630                         0                          0
# ...                          ...                        ...
# 463                            0                          0
# 440                            0                          0
# 428                            0                          0
# 593                            0                          0
# 25                             0                          0
#
#         aus_heiz_alt_pellet_janein  aus_heiz_alt_pumpe_janein  \
# 106718                           0                          0
# 106705                           0                          0
# 106694                           0                          0
# 106639                           0                          0
# 106630                           0                          0
# ...                            ...                        ...
# 463                              0                          0
# 440                              0                          0
# 428                              0                          0
# 593                              1                          0
# 25                               0                          0
#
#         aus_heiz_blockkw_janein aus_heiz_befeuerung  \
# 106718                        0                  Öl
# 106705                        0             Elektro
# 106694                        0             Elektro
# 106639                        0                 NaN
# 106630                        0                 Gas
# ...                         ...                 ...
# 463                           0                  Öl
# 440                           0                 Gas
# 428                           0                 Gas
# 593                           0          Alternativ
# 25                            0                 Gas
#
#         aus_heiz_fernwaerme_janein  aus_heiz_fussboden_janein  \
# 106718                           0                          0
# 106705                           0                          0
# 106694                           0                          0
# 106639                           0                          0
# 106630                           0                          0
# ...                            ...                        ...
# 463                              0                          0
# 440                              0                          0
# 428                              0                          0
# 593                              0                          0
# 25                               0                          0
#
#         aus_heiz_keine_janein aus_heiz_system  aus_kamin_janein  \
# 106718                      0         Zentral                 0
# 106705                      0           Etage                 0
# 106694                      0             NaN                 0
# 106639                      0             NaN                 0
# 106630                      0         Zentral                 0
# ...                       ...             ...               ...
# 463                         0             NaN                 0
# 440                         0         Zentral                 0
# 428                         0         Zentral                 0
# 593                         0         Zentral                 0
# 25                          0             NaN                 0
#
#         aus_kueche_einbau_janein  aus_kueche_offen_janein  \
# 106718                         1                        0
# 106705                         1                        0
# 106694                         1                        0
# 106639                         1                        0
# 106630                         1                        0
# ...                          ...                      ...
# 463                            1                        0
# 440                            1                        0
# 428                            1                        0
# 593                            1                        0
# 25                             1                        1
#
#         aus_kueche_pantry_janein  aus_lift_janein  aus_moebliert_janein  \
# 106718                         0                0                     0
# 106705                         0                0                     0
# 106694                         0                0                     0
# 106639                         0                0                     0
# 106630                         0                0                     0
# ...                          ...              ...                   ...
# 463                            0                0                     0
# 440                            0                1                     0
# 428                            0                0                     0
# 593                            0                0                     0
# 25                             0                0                     0
#
#         aus_parken_carport_janein  aus_parken_janein  \
# 106718                          0                  0
# 106705                          0                  1
# 106694                          0                  0
# 106639                          0                  1
# 106630                          0                  1
# ...                           ...                ...
# 463                             0                  0
# 440                             0                  1
# 428                             0                  0
# 593                             0                  1
# 25                              0                  0
#
#         aus_parken_ladestation_janein  aus_parken_stellplaetze_janein  \
# 106718                              0                               0
# 106705                              0                               0
# 106694                              0                               0
# 106639                              0                               0
# 106630                              0                               0
# ...                               ...                             ...
# 463                                 0                               0
# 440                                 0                               0
# 428                                 0                               0
# 593                                 0                               0
# 25                                  0                               0
#
#         aus_pool_janein  aus_sauna_janein  baujahr  flaeche  etage  etagen  \
# 106718                0                 0      NaN     87.0    0.0     NaN
# 106705                0                 0      NaN     77.1    NaN     NaN
# 106694                0                 0   1957.0     48.0    NaN     NaN
# 106639                0                 0      NaN     90.0    NaN     NaN
# 106630                0                 0      NaN     93.0    NaN     NaN
# ...                 ...               ...      ...      ...    ...     ...
# 463                   0                 0   1991.0     70.0    2.0     3.0
# 440                   0                 0   2010.0    124.0    0.5     NaN
# 428                   0                 0      NaN     68.0    3.0     NaN
# 593                   0                 0   1992.0     69.0    NaN     NaN
# 25                    0                 0   1980.0     58.0    2.0     3.0
#
#         fl_wohnen  kosten  kosten_je_flaeche  kosten_miete_gesamt_janein  \
# 106718       87.0   630.0               7.24                           0
# 106705       77.1   650.0               8.43                           0
# 106694       48.0   420.0               8.75                           0
# 106639       90.0   770.0               8.56                           0
# 106630       93.0   980.0              10.54                           0
# ...           ...     ...                ...                         ...
# 463          70.0   770.0              11.00                           0
# 440         124.0  1670.0              13.47                           0
# 428          68.0   640.0               9.41                           0
# 593          69.0  1300.0              18.84                           0
# 25           58.0   870.0              15.00                           0
#
#         kstn_betriebskosten  kstn_betriebskosten_pqm  kstn_heizung  \
# 106718                  NaN                      NaN           NaN
# 106705                  NaN                      NaN           NaN
# 106694                  NaN                      NaN           NaN
# 106639                  NaN                      NaN           NaN
# 106630                  NaN                      NaN           NaN
# ...                     ...                      ...           ...
# 463                     NaN                      NaN           NaN
# 440                     NaN                      NaN           NaN
# 428                     NaN                      NaN           NaN
# 593                     NaN                      NaN           NaN
# 25                      NaN                      NaN         170.0
#
#         laufzeitw_alle  laufzeitw_geschl nachfrageart nutzungsart  oadr_bl  \
# 106718           186.9             186.9        miete        Wohn        8
# 106705            38.1              38.1        miete        Wohn        8
# 106694            31.7              31.7        miete        Wohn        8
# 106639            23.1              23.1        miete        Wohn        8
# 106630            19.4              19.4        miete        Wohn        8
# ...                ...               ...          ...         ...      ...
# 463                0.6               0.6        miete        Wohn        8
# 440                0.2               0.2        miete        Wohn        8
# 428                0.8               0.8        miete        Wohn        8
# 593                1.8               1.8        miete        Wohn        8
# 25                 0.2               NaN        miete        Wohn        8
#
#         oadr_gkz  oadr_kkz  kstn_nebenkosten  kstn_miete_kalt  \
# 106718   8416041      8416             150.0            630.0
# 106705   8416041      8416             130.0            650.0
# 106694   8416041      8416              50.0            420.0
# 106639   8416041      8416             170.0            770.0
# 106630   8416041      8416             140.0            980.0
# ...          ...       ...               ...              ...
# 463      8416041      8416             130.0            770.0
# 440      8416041      8416             350.0           1670.0
# 428      8416041      8416             110.0            640.0
# 593      8416041      8416             250.0           1300.0
# 25       8416041      8416             170.0            870.0
#
#         kstn_miete_gesamt  kstn_miete_gesamt_pqm  kstn_miete_kalt_pqm  \
# 106718              780.0                   8.97                 7.24
# 106705              780.0                  10.12                 8.43
# 106694              470.0                   9.79                 8.75
# 106639              940.0                  10.44                 8.56
# 106630             1120.0                  12.04                10.54
# ...                   ...                    ...                  ...
# 463                 900.0                  12.86                11.00
# 440                2020.0                  16.29                13.47
# 428                 750.0                  11.03                 9.41
# 593                1650.0                  23.91                18.84
# 25                 1040.0                  17.93                15.00
#
#         kstn_kaufpreis  kstn_kaufpreis_pqm  kstn_heizung_pqm oadr_kreis  \
# 106718             NaN                 NaN               NaN   Tübingen
# 106705             NaN                 NaN               NaN   Tübingen
# 106694             NaN                 NaN               NaN   Tübingen
# 106639             NaN                 NaN               NaN   Tübingen
# 106630             NaN                 NaN               NaN   Tübingen
# ...                ...                 ...               ...        ...
# 463                NaN                 NaN               NaN   Tübingen
# 440                NaN                 NaN               NaN   Tübingen
# 428                NaN                 NaN               NaN   Tübingen
# 593                NaN                 NaN               NaN   Tübingen
# 25                 NaN                 NaN              2.93   Tübingen
#
#         oadr_ort  oadr_plz        oadr_u1                   oadr_u2 objektart  \
# 106718  Tübingen     72070  Unterjesingen             Unterjesingen   Einheit
# 106705  Tübingen     72070       Tübingen                 Weststadt   Einheit
# 106694  Tübingen     72074       Tübingen               Universität   Einheit
# 106639  Tübingen     72076       Tübingen                     Wanne   Einheit
# 106630  Tübingen     72072    Derendingen  Feuerhägle/Mühlenviertel   Einheit
# ...          ...       ...            ...                       ...       ...
# 463     Tübingen     72074      Pfrondorf                 Pfrondorf   Einheit
# 440     Tübingen     72070       Tübingen                 Weststadt   Einheit
# 428     Tübingen     72070       Tübingen                 Weststadt   Einheit
# 593     Tübingen     72070       Tübingen                 Weststadt   Einheit
# 25      Tübingen     72070       Tübingen                   Zentrum   Einheit
#
#        objekttyp objekttyp_fein objekttyp_grob  oeig_altbau_janein  \
# 106718   Wohnung        4-Z-Whg        Wohnung                   0
# 106705   Wohnung        2-Z-Whg        Wohnung                   0
# 106694   Wohnung        2-Z-Whg        Wohnung                   0
# 106639   Wohnung        2-Z-Whg        Wohnung                   0
# 106630   Wohnung        3-Z-Whg        Wohnung                   0
# ...          ...            ...            ...                 ...
# 463      Wohnung        2-Z-Whg        Wohnung                   0
# 440      Wohnung       4+-Z-Whg        Wohnung                   0
# 428      Wohnung        3-Z-Whg        Wohnung                   0
# 593      Wohnung        2-Z-Whg        Wohnung                   0
# 25       Wohnung        2-Z-Whg        Wohnung                   0
#
#         zust_saniert_janein  zust_neuwertig_janein  zust_projektiert_janein  \
# 106718                    0                      0                        0
# 106705                    0                      0                        0
# 106694                    0                      0                        0
# 106639                    0                      0                        0
# 106630                    1                      0                        0
# ...                     ...                    ...                      ...
# 463                       0                      0                        0
# 440                       0                      0                        0
# 428                       1                      0                        0
# 593                       0                      0                        0
# 25                        0                      1                        0
#
#         zust_modernisierungsjahr  zust_gepflegt_janein   startdate segment  \
# 106718                       NaN                     0  2010-10-15   WHG_M
# 106705                    2011.0                     0  2011-07-23   WHG_M
# 106694                       NaN                     0  2011-08-02   WHG_M
# 106639                       NaN                     0  2011-10-04   WHG_M
# 106630                       NaN                     0  2011-10-31   WHG_M
# ...                          ...                   ...         ...     ...
# 463                          NaN                     1  2023-12-12   WHG_M
# 440                          NaN                     1  2023-12-12   WHG_M
# 428                          NaN                     1  2023-12-12   WHG_M
# 593                          NaN                     1  2023-12-07   WHG_M
# 25                           NaN                     0  2023-12-30   WHG_M
#
#         oeig_wbs_janein  oeig_vermietet_janein  oeig_reihenendhaus_janein3  \
# 106718                0                      0                           0
# 106705                0                      0                           0
# 106694                0                      0                           0
# 106639                0                      0                           0
# 106630                0                      0                           0
# ...                 ...                    ...                         ...
# 463                   0                      0                           0
# 440                   0                      0                           0
# 428                   0                      0                           0
# 593                   0                      0                           0
# 25                    0                      0                           0
#
#         oeig_neubau_janein  oeig_loggia_janein  oeig_keller_janein  \
# 106718                   0                   0                   1
# 106705                   0                   0                   1
# 106694                   0                   0                   1
# 106639                   0                   0                   0
# 106630                   0                   0                   1
# ...                    ...                 ...                 ...
# 463                      0                   0                   1
# 440                      0                   0                   1
# 428                      0                   0                   0
# 593                      0                   0                   0
# 25                       0                   0                   1
#
#         oeig_freistehend_janein  oeig_denkmal_janein  \
# 106718                        0                    0
# 106705                        0                    0
# 106694                        0                    0
# 106639                        0                    0
# 106630                        0                    0
# ...                         ...                  ...
# 463                           0                    0
# 440                           0                   -1
# 428                           0                    0
# 593                           0                    0
# 25                            0                    0
#
#         oeig_dachgeschoss_janein     enddate  aus_balkon_terrasse_janein  \
# 106718                        -1  2014-05-15                           1
# 106705                         0  2012-04-15                           1
# 106694                         0  2012-03-11                           1
# 106639                         0  2012-03-14                           0
# 106630                         0  2012-03-15                           0
# ...                          ...         ...                         ...
# 463                            1  2023-12-16                           1
# 440                           -1  2023-12-14                           1
# 428                            0  2023-12-18                           0
# 593                            0  2023-12-20                           1
# 25                             1  2024-01-02                           0
#
#         aus_wintergarten_janein  aus_garten_eigen_janein  year endyear  month  \
# 106718                        0                        0  2010    2014     10
# 106705                        0                        0  2011    2012      7
# 106694                        0                        0  2011    2012      8
# 106639                        0                        0  2011    2012     10
# 106630                        0                        0  2011    2012     10
# ...                         ...                      ...   ...     ...    ...
# 463                           0                        0  2023    2023     12
# 440                           0                       -1  2023    2023     12
# 428                           0                        0  2023    2023     12
# 593                           0                        0  2023    2023     12
# 25                            0                        0  2023    2024     12
#
#        year_month
# 106718    2010-10
# 106705    2011-07
# 106694    2011-08
# 106639    2011-10
# 106630    2011-10
# ...           ...
# 463       2023-12
# 440       2023-12
# 428       2023-12
# 593       2023-12
# 25        2023-12
#
# [6300 rows x 90 columns]

# %%
df_w_loc_interesting = df_w_loc[df_w_loc["oadr_u2"].isin(interesting_regions)]
# scatter plot with seaborn
sns.set_theme(style="whitegrid")
plt.figure(figsize=(12, 6))
ax = sns.scatterplot(data=df_w_loc_interesting, x="year_month", y="kstn_miete_kalt_pqm", hue="oadr_u2")
plt.title('Rent per Square Meter Over Time')
plt.xlabel('Year-Month')
plt.xticks(df_w_loc_interesting['year_month'].unique()[::6], rotation=45)
plt.ylabel('Rent per Square Meter')
plt.legend()
plt.show()

# %% [markdown]
# ## Linear regression
# Weil wir als X-Werte das Datum haben, können wir nicht einfach linear regression anwenden. Wir gehen wie folgt vor:
# 1) Wir ändern unsere Werte zu ordinalen Werten
# 2) Splitten x und y
# 3) Fitten die Kurve
# 4) Ploten die Kurve in die scatter plots rein

# %% [markdown]
# ### 1) Ordinal values

# %%
df_w_loc_interesting_copy = df_w_loc_interesting.copy()
df_w_loc_interesting_copy["startdate"]
# Out:
# 106718    2010-10-15
# 106705    2011-07-23
# 106694    2011-08-02
# 106639    2011-10-04
# 106630    2011-10-31
#              ...
# 463       2023-12-12
# 440       2023-12-12
# 428       2023-12-12
# 593       2023-12-07
# 25        2023-12-30
# Name: startdate, Length: 6300, dtype: object

# %%
import datetime as dt
df_w_loc_interesting_copy['startdate'] = pd.to_datetime(df_w_loc_interesting_copy['startdate'])
df_w_loc_interesting_copy['startdate_ordinal']=df_w_loc_interesting_copy['startdate'].map(dt.datetime.toordinal)
df_w_loc_interesting_copy['startdate_ordinal']
# Out:
# 106718    734060
# 106705    734341
# 106694    734351
# 106639    734414
# 106630    734441
#            ...
# 463       738866
# 440       738866
# 428       738866
# 593       738861
# 25        738884
# Name: startdate_ordinal, Length: 6300, dtype: int64

# %% [markdown]
# ### 2) Split x and y

# %%
from sklearn.linear_model import LinearRegression

# %%
df_w_loc_interesting_copy["kstn_miete_kalt_pqm"].isna().sum()
# Out:
# 0

# %%
df_w_loc_interesting_copy["startdate"].unique()
# Out:
# <DatetimeArray>
# ['2010-10-15 00:00:00', '2011-07-23 00:00:00', '2011-08-02 00:00:00',
#  '2011-10-04 00:00:00', '2011-10-31 00:00:00', '2011-11-09 00:00:00',
#  '2011-12-30 00:00:00', '2011-12-29 00:00:00', '2011-12-28 00:00:00',
#  '2011-12-27 00:00:00',
#  ...
#  '2023-12-07 00:00:00', '2023-12-12 00:00:00', '2023-12-02 00:00:00',
#  '2023-12-03 00:00:00', '2023-12-04 00:00:00', '2023-12-05 00:00:00',
#  '2023-12-06 00:00:00', '2023-12-09 00:00:00', '2023-12-11 00:00:00',
#  '2023-12-30 00:00:00']
# Length: 3082, dtype: datetime64[ns]

# %%
lg_df = pd.DataFrame(columns=["oadr_u2", "r_sq", "intercept", "slope"])
df_w_loc_interesting_copy=df_w_loc_interesting_copy.sort_values(by=["oadr_u2", 'startdate_ordinal'])
for i in interesting_regions:
    x = df_w_loc_interesting_copy.loc[df_w_loc_interesting_copy["oadr_u2"] == i, "startdate_ordinal"]
    
    y = df_w_loc_interesting_copy.loc[df_w_loc_interesting_copy["oadr_u2"] == i, "kstn_miete_kalt_pqm"]
    x = x.values.reshape(-1, 1)
    print(i)
    model = LinearRegression().fit(x, y)
    r_sq = model.score(x, y)
    intercept = model.intercept_
    slope=model.coef_[0]
    lg_df = lg_df._append({"oadr_u2": i, "r_sq": r_sq, "intercept": intercept, "slope": slope}, ignore_index=True)
lg_df
# Out:
# Zentrum
# Unterjesingen
# Bühl
# Universität
# Wanne
# Weilheim
# De-Zentrum
# Schönblick/Waldhäuser Ost
# Weststadt
# Österberg/Gartenstraße
# Bebenhausen
# Denzenberg/Sand
# Pfrondorf
# Südstadt
# Hagelloch
# Au/Unterer Wert/Französiches Viertel
# Feuerhägle/Mühlenviertel
# Lustnau-Zentrum/Herrlesberg/Stäudach
# Hirschau
# Kilchberg
# Neuhalde
# Aeule
# Gartenstadt
#                                  oadr_u2      r_sq    intercept     slope
# 0                                Zentrum  0.178785  -788.834277  0.001087
# 1                          Unterjesingen  0.285106  -649.616715  0.000895
# 2                                   Bühl  0.297118  -880.410839  0.001209
# 3                            Universität  0.138383  -622.217234  0.000860
# 4                                  Wanne  0.236807  -714.501564  0.000986
# 5                               Weilheim  0.236790  -555.229874  0.000767
# 6                             De-Zentrum  0.297820 -1059.910459  0.001454
# 7              Schönblick/Waldhäuser Ost  0.204229  -713.434855  0.000984
# 8                              Weststadt  0.173418  -646.016777  0.000893
# 9                 Österberg/Gartenstraße  0.205345  -665.118626  0.000919
# 10                           Bebenhausen  0.396550  -689.602340  0.000950
# 11                       Denzenberg/Sand  0.149606  -695.300884  0.000960
# 12                             Pfrondorf  0.270402  -649.136386  0.000897
# 13                              Südstadt  0.209954  -838.872461  0.001155
# 14                             Hagelloch  0.328302  -862.369388  0.001185
# 15  Au/Unterer Wert/Französiches Viertel  0.258723 -1060.041395  0.001456
# 16              Feuerhägle/Mühlenviertel  0.057837  -376.587480  0.000527
# 17  Lustnau-Zentrum/Herrlesberg/Stäudach  0.199778  -817.703350  0.001126
# 18                              Hirschau  0.306460  -748.375114  0.001030
# 19                             Kilchberg  0.458362  -693.581648  0.000955
# 20                              Neuhalde  0.138004  -941.858885  0.001295
# 21                                 Aeule  0.079618  -628.838743  0.000872
# 22                           Gartenstadt  0.035663  -493.250178  0.000684

# %%
lg_df = pd.DataFrame(columns=["oadr_u2", "r_sq", "intercept", "slope", "p_val"])
df_w_loc_interesting_copy=df_w_loc_interesting_copy.sort_values(by=["oadr_u2", 'startdate_ordinal'])
for i in interesting_regions:
    x = df_w_loc_interesting_copy.loc[df_w_loc_interesting_copy["oadr_u2"] == i, "startdate_ordinal"]
    y = df_w_loc_interesting_copy.loc[df_w_loc_interesting_copy["oadr_u2"] == i, "kstn_miete_kalt_pqm"]
    test_result = linregress(x=x, y=y)
    print(test_result)
    x = x.values.reshape(-1, 1)
    print(i)
    model = LinearRegression().fit(x, y)
    r_sq = model.score(x, y)
 
    intercept = model.intercept_
    slope=model.coef_[0]
    lg_df = lg_df._append({"oadr_u2": i, "r_sq": r_sq, "intercept": intercept, "slope": slope, "p_val":test_result.pvalue} ,ignore_index=True)
lg_df.sort_values(by=["slope"])
# Out:
# LinregressResult(slope=0.0010865238055873007, intercept=-788.8342767482856, rvalue=0.4228302607535664, pvalue=1.5516335200760753e-23, stderr=0.00010331649209668351, intercept_stderr=76.15155946555672)
# Zentrum
# LinregressResult(slope=0.000895370372342524, intercept=-649.6167145023774, rvalue=0.5339530599406775, pvalue=1.520385504394486e-15, stderr=0.00010285933326019487, intercept_stderr=75.76215429396683)
# Unterjesingen
# LinregressResult(slope=0.0012087817161538024, intercept=-880.4108394055743, rvalue=0.5450850889639776, pvalue=1.706524474814424e-17, stderr=0.00012953623111775395, intercept_stderr=95.43954934224043)
# Bühl
# LinregressResult(slope=0.0008603661514379388, intercept=-622.2172341429946, rvalue=0.371999075334012, pvalue=2.2382621706478006e-28, stderr=7.497070250739744e-05, intercept_stderr=55.25576106045365)
# Universität
# LinregressResult(slope=0.0009855562653082674, intercept=-714.5015638188784, rvalue=0.48662813122270493, pvalue=6.894743770005921e-27, stderr=8.562241661144195e-05, intercept_stderr=63.094534039507614)
# Wanne
# LinregressResult(slope=0.0007669496079516374, intercept=-555.2298740067666, rvalue=0.4866108628288322, pvalue=2.2402225643340272e-05, stderr=0.00016821689691855096, intercept_stderr=123.90390740048117)
# Weilheim
# LinregressResult(slope=0.001453524582173952, intercept=-1059.9104592358358, rvalue=0.5457289875879808, pvalue=1.4872314059021102e-06, stderr=0.0002747246182014046, intercept_stderr=202.54498178972904)
# De-Zentrum
# LinregressResult(slope=0.0009835185917209822, intercept=-713.4348547145187, rvalue=0.4519169775795214, pvalue=1.1037703516670617e-24, stderr=9.042062832026927e-05, intercept_stderr=66.63263731829899)
# Schönblick/Waldhäuser Ost
# LinregressResult(slope=0.0008931923261302476, intercept=-646.016777126381, rvalue=0.41643526615559207, pvalue=2.5520057515960044e-31, stderr=7.308030820990736e-05, intercept_stderr=53.857353914543566)
# Weststadt
# LinregressResult(slope=0.0009193141034432598, intercept=-665.118625591456, rvalue=0.45314989967388875, pvalue=6.513296771224597e-09, stderr=0.0001491601197780096, intercept_stderr=109.88818090396941)
# Österberg/Gartenstraße
# LinregressResult(slope=0.0009501102837798747, intercept=-689.6023397485534, rvalue=0.6297223809796886, pvalue=1.3396092383373792e-05, stderr=0.00019013130880806426, intercept_stderr=140.11297157743934)
# Bebenhausen
# LinregressResult(slope=0.0009600366397742989, intercept=-695.3008841303518, rvalue=0.38678883137536507, pvalue=1.82596687684349e-06, stderr=0.00019275893690064893, intercept_stderr=142.07114922906894)
# Denzenberg/Sand
# LinregressResult(slope=0.0008967402589183716, intercept=-649.1363855697883, rvalue=0.5200023341307921, pvalue=1.6030200250034374e-20, stderr=8.898724950812225e-05, intercept_stderr=65.55748943832025)
# Pfrondorf
# LinregressResult(slope=0.0011545570777060357, intercept=-838.8724612094451, rvalue=0.45820772441061947, pvalue=6.255248915373148e-36, stderr=8.684969163448709e-05, intercept_stderr=64.01398432384535)
# Südstadt
# LinregressResult(slope=0.0011854020026645408, intercept=-862.3693876034723, rvalue=0.5729762577345237, pvalue=3.551916805111059e-12, stderr=0.0001535098366432531, intercept_stderr=113.07258338217937)
# Hagelloch
# LinregressResult(slope=0.0014559703134514508, intercept=-1060.04139496134, rvalue=0.5086486873786927, pvalue=8.632043567750824e-27, stderr=0.00012576479859183526, intercept_stderr=92.72527164760729)
# Au/Unterer Wert/Französiches Viertel
# LinregressResult(slope=0.0005274933631379858, intercept=-376.5874800505098, rvalue=0.24049292039413628, pvalue=0.000424316892275858, stderr=0.000147266721580414, intercept_stderr=108.54972134421651)
# Feuerhägle/Mühlenviertel
# LinregressResult(slope=0.0011258189523008003, intercept=-817.703350282424, rvalue=0.44696550882012903, pvalue=1.8277330805713552e-17, stderr=0.00012498504828031693, intercept_stderr=92.07913593532373)
# Lustnau-Zentrum/Herrlesberg/Stäudach
# LinregressResult(slope=0.0010300892384095242, intercept=-748.3751142947887, rvalue=0.553588632484462, pvalue=1.5850199445905222e-24, stderr=9.16305534602446e-05, intercept_stderr=67.48779540475388)
# Hirschau
# LinregressResult(slope=0.0009550959280842108, intercept=-693.5816482446828, rvalue=0.6770243171140564, pvalue=3.1724861489952294e-10, stderr=0.00012877769280901673, intercept_stderr=94.83886899703715)
# Kilchberg
# LinregressResult(slope=0.001295348362944959, intercept=-941.8588846258037, rvalue=0.3714891066400817, pvalue=0.0005030594878415792, stderr=0.0003575083231175405, intercept_stderr=263.4878434565716)
# Neuhalde
# LinregressResult(slope=0.0008720050934513196, intercept=-628.8387425655819, rvalue=0.2821657662609382, pvalue=0.05200942558050441, stderr=0.00043713940376408447, intercept_stderr=322.18855824756133)
# Aeule
# LinregressResult(slope=0.0006842954480729048, intercept=-493.2501779167237, rvalue=0.18884635234566194, pvalue=0.500277980703981, stderr=0.0009869105733111237, intercept_stderr=726.7955366228263)
# Gartenstadt
#                                  oadr_u2      r_sq    intercept     slope  \
# 16              Feuerhägle/Mühlenviertel  0.057837  -376.587480  0.000527
# 22                           Gartenstadt  0.035663  -493.250178  0.000684
# 5                               Weilheim  0.236790  -555.229874  0.000767
# 3                            Universität  0.138383  -622.217234  0.000860
# 21                                 Aeule  0.079618  -628.838743  0.000872
# 8                              Weststadt  0.173418  -646.016777  0.000893
# 1                          Unterjesingen  0.285106  -649.616715  0.000895
# 12                             Pfrondorf  0.270402  -649.136386  0.000897
# 9                 Österberg/Gartenstraße  0.205345  -665.118626  0.000919
# 10                           Bebenhausen  0.396550  -689.602340  0.000950
# 19                             Kilchberg  0.458362  -693.581648  0.000955
# 11                       Denzenberg/Sand  0.149606  -695.300884  0.000960
# 7              Schönblick/Waldhäuser Ost  0.204229  -713.434855  0.000984
# 4                                  Wanne  0.236807  -714.501564  0.000986
# 18                              Hirschau  0.306460  -748.375114  0.001030
# 0                                Zentrum  0.178785  -788.834277  0.001087
# 17  Lustnau-Zentrum/Herrlesberg/Stäudach  0.199778  -817.703350  0.001126
# 13                              Südstadt  0.209954  -838.872461  0.001155
# 14                             Hagelloch  0.328302  -862.369388  0.001185
# 2                                   Bühl  0.297118  -880.410839  0.001209
# 20                              Neuhalde  0.138004  -941.858885  0.001295
# 6                             De-Zentrum  0.297820 -1059.910459  0.001454
# 15  Au/Unterer Wert/Französiches Viertel  0.258723 -1060.041395  0.001456
#
#            p_val
# 16  4.243169e-04
# 22  5.002780e-01
# 5   2.240223e-05
# 3   2.238262e-28
# 21  5.200943e-02
# 8   2.552006e-31
# 1   1.520386e-15
# 12  1.603020e-20
# 9   6.513297e-09
# 10  1.339609e-05
# 19  3.172486e-10
# 11  1.825967e-06
# 7   1.103770e-24
# 4   6.894744e-27
# 18  1.585020e-24
# 0   1.551634e-23
# 17  1.827733e-17
# 13  6.255249e-36
# 14  3.551917e-12
# 2   1.706524e-17
# 20  5.030595e-04
# 6   1.487231e-06
# 15  8.632044e-27

# %%
lg_df["jahresanstieg"]=lg_df["slope"]*365
lg_df
# Out:
#                                  oadr_u2      r_sq    intercept     slope  \
# 0                                Zentrum  0.178785  -788.834277  0.001087
# 1                          Unterjesingen  0.285106  -649.616715  0.000895
# 2                                   Bühl  0.297118  -880.410839  0.001209
# 3                            Universität  0.138383  -622.217234  0.000860
# 4                                  Wanne  0.236807  -714.501564  0.000986
# 5                               Weilheim  0.236790  -555.229874  0.000767
# 6                             De-Zentrum  0.297820 -1059.910459  0.001454
# 7              Schönblick/Waldhäuser Ost  0.204229  -713.434855  0.000984
# 8                              Weststadt  0.173418  -646.016777  0.000893
# 9                 Österberg/Gartenstraße  0.205345  -665.118626  0.000919
# 10                           Bebenhausen  0.396550  -689.602340  0.000950
# 11                       Denzenberg/Sand  0.149606  -695.300884  0.000960
# 12                             Pfrondorf  0.270402  -649.136386  0.000897
# 13                              Südstadt  0.209954  -838.872461  0.001155
# 14                             Hagelloch  0.328302  -862.369388  0.001185
# 15  Au/Unterer Wert/Französiches Viertel  0.258723 -1060.041395  0.001456
# 16              Feuerhägle/Mühlenviertel  0.057837  -376.587480  0.000527
# 17  Lustnau-Zentrum/Herrlesberg/Stäudach  0.199778  -817.703350  0.001126
# 18                              Hirschau  0.306460  -748.375114  0.001030
# 19                             Kilchberg  0.458362  -693.581648  0.000955
# 20                              Neuhalde  0.138004  -941.858885  0.001295
# 21                                 Aeule  0.079618  -628.838743  0.000872
# 22                           Gartenstadt  0.035663  -493.250178  0.000684
#
#            p_val  jahresanstieg
# 0   1.551634e-23       0.396581
# 1   1.520386e-15       0.326810
# 2   1.706524e-17       0.441205
# 3   2.238262e-28       0.314034
# 4   6.894744e-27       0.359728
# 5   2.240223e-05       0.279937
# 6   1.487231e-06       0.530536
# 7   1.103770e-24       0.358984
# 8   2.552006e-31       0.326015
# 9   6.513297e-09       0.335550
# 10  1.339609e-05       0.346790
# 11  1.825967e-06       0.350413
# 12  1.603020e-20       0.327310
# 13  6.255249e-36       0.421413
# 14  3.551917e-12       0.432672
# 15  8.632044e-27       0.531429
# 16  4.243169e-04       0.192535
# 17  1.827733e-17       0.410924
# 18  1.585020e-24       0.375983
# 19  3.172486e-10       0.348610
# 20  5.030595e-04       0.472802
# 21  5.200943e-02       0.318282
# 22  5.002780e-01       0.249768

# %%
# withhout slope
lg_df_lat = lg_df.drop(columns=["slope"])
lg_df_lat = lg_df_lat.sort_values(by=["jahresanstieg"])
lg_df_lat
# Out:
#                                  oadr_u2      r_sq    intercept         p_val  \
# 16              Feuerhägle/Mühlenviertel  0.057837  -376.587480  4.243169e-04
# 22                           Gartenstadt  0.035663  -493.250178  5.002780e-01
# 5                               Weilheim  0.236790  -555.229874  2.240223e-05
# 3                            Universität  0.138383  -622.217234  2.238262e-28
# 21                                 Aeule  0.079618  -628.838743  5.200943e-02
# 8                              Weststadt  0.173418  -646.016777  2.552006e-31
# 1                          Unterjesingen  0.285106  -649.616715  1.520386e-15
# 12                             Pfrondorf  0.270402  -649.136386  1.603020e-20
# 9                 Österberg/Gartenstraße  0.205345  -665.118626  6.513297e-09
# 10                           Bebenhausen  0.396550  -689.602340  1.339609e-05
# 19                             Kilchberg  0.458362  -693.581648  3.172486e-10
# 11                       Denzenberg/Sand  0.149606  -695.300884  1.825967e-06
# 7              Schönblick/Waldhäuser Ost  0.204229  -713.434855  1.103770e-24
# 4                                  Wanne  0.236807  -714.501564  6.894744e-27
# 18                              Hirschau  0.306460  -748.375114  1.585020e-24
# 0                                Zentrum  0.178785  -788.834277  1.551634e-23
# 17  Lustnau-Zentrum/Herrlesberg/Stäudach  0.199778  -817.703350  1.827733e-17
# 13                              Südstadt  0.209954  -838.872461  6.255249e-36
# 14                             Hagelloch  0.328302  -862.369388  3.551917e-12
# 2                                   Bühl  0.297118  -880.410839  1.706524e-17
# 20                              Neuhalde  0.138004  -941.858885  5.030595e-04
# 6                             De-Zentrum  0.297820 -1059.910459  1.487231e-06
# 15  Au/Unterer Wert/Französiches Viertel  0.258723 -1060.041395  8.632044e-27
#
#     jahresanstieg
# 16       0.192535
# 22       0.249768
# 5        0.279937
# 3        0.314034
# 21       0.318282
# 8        0.326015
# 1        0.326810
# 12       0.327310
# 9        0.335550
# 10       0.346790
# 19       0.348610
# 11       0.350413
# 7        0.358984
# 4        0.359728
# 18       0.375983
# 0        0.396581
# 17       0.410924
# 13       0.421413
# 14       0.432672
# 2        0.441205
# 20       0.472802
# 6        0.530536
# 15       0.531429

# %%
print(lg_df_lat.to_latex(index=False,
                  formatters={"name": str.upper},
                  float_format="{:.3f}".format,
))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# oadr_u2 & r_sq & intercept & p_val & jahresanstieg \\
# \midrule
# Feuerhägle/Mühlenviertel & 0.058 & -376.587 & 0.000 & 0.193 \\
# Gartenstadt & 0.036 & -493.250 & 0.500 & 0.250 \\
# Weilheim & 0.237 & -555.230 & 0.000 & 0.280 \\
# Universität & 0.138 & -622.217 & 0.000 & 0.314 \\
# Aeule & 0.080 & -628.839 & 0.052 & 0.318 \\
# Weststadt & 0.173 & -646.017 & 0.000 & 0.326 \\
# Unterjesingen & 0.285 & -649.617 & 0.000 & 0.327 \\
# Pfrondorf & 0.270 & -649.136 & 0.000 & 0.327 \\
# Österberg/Gartenstraße & 0.205 & -665.119 & 0.000 & 0.336 \\
# Bebenhausen & 0.397 & -689.602 & 0.000 & 0.347 \\
# Kilchberg & 0.458 & -693.582 & 0.000 & 0.349 \\
# Denzenberg/Sand & 0.150 & -695.301 & 0.000 & 0.350 \\
# Schönblick/Waldhäuser Ost & 0.204 & -713.435 & 0.000 & 0.359 \\
# Wanne & 0.237 & -714.502 & 0.000 & 0.360 \\
# Hirschau & 0.306 & -748.375 & 0.000 & 0.376 \\
# Zentrum & 0.179 & -788.834 & 0.000 & 0.397 \\
# Lustnau-Zentrum/Herrlesberg/Stäudach & 0.200 & -817.703 & 0.000 & 0.411 \\
# Südstadt & 0.210 & -838.872 & 0.000 & 0.421 \\
# Hagelloch & 0.328 & -862.369 & 0.000 & 0.433 \\
# Bühl & 0.297 & -880.411 & 0.000 & 0.441 \\
# Neuhalde & 0.138 & -941.859 & 0.001 & 0.473 \\
# De-Zentrum & 0.298 & -1059.910 & 0.000 & 0.531 \\
# Au/Unterer Wert/Französiches Viertel & 0.259 & -1060.041 & 0.000 & 0.531 \\
# \bottomrule
# \end{tabular}

# %%
import matplotlib.dates as mdates
from datetime import date
# Creating scatter plot with regression line
fig, axs = plt.subplots(2, 2, figsize=(10, 10))  # 2 rows and 2 columns of plots

for i, region in enumerate(['Universität', 'Südstadt', 'Weststadt', 'Zentrum']):
    # Filter data for each region
    region_data = df_w_loc_interesting_copy[df_w_loc_interesting_copy['oadr_u2'] == region]

    # Plotting scatter plot for each region
    ax = axs[i//2, i%2]
    ax.scatter(region_data['startdate_ordinal'], region_data['kstn_miete_kalt_pqm'], label=region)
    slope = lg_df.loc[lg_df["oadr_u2"] == region, "slope"].values[0]
    intercept = lg_df.loc[lg_df["oadr_u2"] == region, "intercept"].values[0]
    # Adding regression line
    x = np.array([region_data['startdate_ordinal'].min(), region_data['startdate_ordinal'].max()])
    y = slope * x + intercept
    ax.plot(x, y, color='red', label='Regression Line')
    new_labels = [date.fromordinal(int(item)) for item in ax.get_xticks()]
    ax.set_xticklabels(new_labels[:-2], rotation=45, fontsize=10)
    ax.set_title(f'Scatter Plot for {region}')
    ax.set_xlabel('Start Date (Ordinal)')
    ax.set_ylabel('Cold Rent per sqm (€)')
    ax.legend()
    # ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    # ax.xaxis.set_major_locator(mdates.AutoDateLocator())

plt.tight_layout()
plt.show()
# Out:
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/2953873384.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels[:-2], rotation=45, fontsize=10)

# %%
df_w_loc_interesting_copy["year"].unique()
# Out:
# array(['2012', '2013', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022', '2023', '2014', '2015', '2011', '2010'], dtype=object)

# %%
df_w_loc_interesting_copy = df_w_loc_interesting_copy[df_w_loc_interesting_copy["year"] !="2024"]

# %%
import matplotlib.pyplot as plt
import numpy as np
from datetime import date

# Annahme: 'df_w_loc_interesting_copy' und 'lg_df' sind bereits definierte DataFrames
selected_regions = ['Feuerhägle/Mühlenviertel', 'Au/Unterer Wert/Französiches Viertel']

# Erstellen des Plots
fig, ax = plt.subplots(figsize=(10, 6))
scatter_plots = []  # To store scatter plot handles for the legend

for region in selected_regions:
    # Filter data for the selected region
    region_data = df_w_loc_interesting_copy[df_w_loc_interesting_copy['oadr_u2'] == region]

    # Creating scatter plot for the selected region
    scatter = ax.scatter(region_data['startdate_ordinal'], region_data['kstn_miete_kalt_pqm'], label=region)
    scatter_plots.append(scatter)

    # Calculating and plotting the regression line
    slope = lg_df.loc[lg_df["oadr_u2"] == region, "slope"].values[0]
    intercept = lg_df.loc[lg_df["oadr_u2"] == region, "intercept"].values[0]
    x = np.array([region_data['startdate_ordinal'].min(), region_data['startdate_ordinal'].max()])
    y = slope * x + intercept
    ax.plot(x, y)

# Formatting the plot
ax.set_title('Scatter Plot and Regression for Selected Regions')
ax.set_xlabel('Start Date (Ordinal)')
ax.set_ylabel('Cold Rent per sqm (€)')
new_labels = [date.fromordinal(int(item)) for item in ax.get_xticks()]
ax.set_xticklabels(new_labels[:-2], rotation=45, fontsize=10)

# Creating custom legend for scatter plots only
ax.legend(handles=scatter_plots, labels=selected_regions)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/4074625453.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels[:-2], rotation=45, fontsize=10)

# %% [markdown]
# ## Gesamt regression für Tübingen

# %% [markdown]
# ### Ich nehme jetzt den gesamten Datensatz, nicht nur die wo wir für oadr_u2 was haben

# %%
df.shape
# Out:
# (9935, 89)

# %%
df_complete = df[df["kstn_miete_kalt_pqm"].notna()]

# %%
df_complete.shape
# Out:
# (9935, 89)

# %%
df_complete["startdate"] = pd.to_datetime(df_complete["startdate"])
df_complete["startdate_ordinal"]=df_complete["startdate"].map(dt.datetime.toordinal)
df_complete["startdate_ordinal"]
# Out:
# 13        738884
# 25        738884
# 34        738883
# 36        738883
# 55        738882
#            ...
# 106694    734351
# 106702    734343
# 106705    734341
# 106717    734060
# 106718    734060
# Name: startdate_ordinal, Length: 9935, dtype: int64

# %%
m = LinearRegression().fit(df_complete["startdate_ordinal"].values.reshape(-1, 1), df_complete["kstn_miete_kalt_pqm"])
r_sq = m.score(df_complete["startdate_ordinal"].values.reshape(-1, 1), df_complete["kstn_miete_kalt_pqm"])
print('coefficient of determination:', r_sq)
print('intercept:', m.intercept_)
print('slope:', m.coef_)
# Out:
# coefficient of determination: 0.22491195838809008
# intercept: -759.2669890876152
# slope: [0.00104639]

# %%
df_complete = df_complete.sort_values(by=["startdate_ordinal"])
x = df_complete["startdate_ordinal"]
y = df_complete["kstn_miete_kalt_pqm"]
model = linregress(x=x, y=y)
print(model)
tue_slope = model.slope
tue_intercept = model.intercept
# Out:
# LinregressResult(slope=0.0010463900979493395, intercept=-759.2669890876211, rvalue=0.47424883593751677, pvalue=0.0, stderr=1.9490485088066583e-05, intercept_stderr=14.359600129868628)

# %% [markdown]
# ## Dient nur als Verifizierung für den händisch berechnen Ansatz eins drunter

# %%
sns.regplot(data=df_complete, x= "startdate_ordinal", y="kstn_miete_kalt_pqm", line_kws={"color": "red"})
# Out:
# <Axes: xlabel='startdate_ordinal', ylabel='kstn_miete_kalt_pqm'>

# %%
import matplotlib.pyplot as plt
import numpy as np
from datetime import date

# Annahme: 'df_w_loc_interesting_copy' und 'lg_df' sind bereits definierte DataFrames
selected_regions = ['Feuerhägle/Mühlenviertel', 'Au/Unterer Wert/Französiches Viertel']

# Erstellen des Plots
fig, ax = plt.subplots(figsize=(10, 6))
scatter_plots = []  # To store scatter plot handles for the legend

for region in selected_regions:
    # Filter data for the selected region
    region_data = df_w_loc_interesting_copy[df_w_loc_interesting_copy['oadr_u2'] == region]

    # Creating scatter plot for the selected region
    scatter = ax.scatter(region_data['startdate_ordinal'], region_data['kstn_miete_kalt_pqm'], label=region)
    scatter_plots.append(scatter)

    # Calculating and plotting the regression line
    slope = lg_df.loc[lg_df["oadr_u2"] == region, "slope"].values[0]
    intercept = lg_df.loc[lg_df["oadr_u2"] == region, "intercept"].values[0]
    x = np.array([region_data['startdate_ordinal'].min(), region_data['startdate_ordinal'].max()])
    y = slope * x + intercept
    ax.plot(x, y)
   
x_tue = np.array([df_complete['startdate_ordinal'].min(), df_complete['startdate_ordinal'].max()])
y_tue = tue_slope * x_tue + tue_intercept
ax.plot(x_tue, y_tue, color="black", label="Tübingen")
# Formatting the plot
ax.set_title('Scatter Plot and Regression for Selected Regions')
ax.set_xlabel('Start Date (Ordinal)')
ax.set_ylabel('Cold Rent per sqm (€)')
new_labels = [date.fromordinal(int(item)) for item in ax.get_xticks()]
ax.set_xticklabels(new_labels[:-2], rotation=45, fontsize=10)

# Creating custom legend for scatter plots only
ax.legend(handles=scatter_plots, labels=selected_regions)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/3337273802.py:35: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels[:-2], rotation=45, fontsize=10)

# %% [markdown]
# ## Add label in legend

# %%
import matplotlib.pyplot as plt
import numpy as np
from datetime import date

# Assuming 'df_w_loc_interesting_copy', 'lg_df', and 'df_complete' are predefined DataFrames
selected_regions = ['Feuerhägle/Mühlenviertel', 'Au/Unterer Wert/Französiches Viertel']

# Creating the plot
fig, ax = plt.subplots(figsize=(10, 6))
scatter_plots = []  # To store scatter plot handles for the legend

for region in selected_regions:
    # Filter data for the selected region
    region_data = df_w_loc_interesting_copy[df_w_loc_interesting_copy['oadr_u2'] == region]

    # Creating scatter plot for the selected region
    scatter = ax.scatter(region_data['startdate_ordinal'], region_data['kstn_miete_kalt_pqm'], label=region)
    scatter_plots.append(scatter)

    # Calculating and plotting the regression line for each region
    slope = lg_df.loc[lg_df["oadr_u2"] == region, "slope"].values[0]
    intercept = lg_df.loc[lg_df["oadr_u2"] == region, "intercept"].values[0]
    x = np.array([region_data['startdate_ordinal'].min(), region_data['startdate_ordinal'].max()])
    y = slope * x + intercept
    ax.plot(x, y)

# Adding the overall regression line for 'All data'
x_tue = np.array([df_complete['startdate_ordinal'].min(), df_complete['startdate_ordinal'].max()])
y_tue = tue_slope * x_tue + tue_intercept
line_all_data, = ax.plot(x_tue, y_tue, color="black", label="Tübingen")

# Formatting the plot
ax.set_title('Scatter Plot and Regression for Selected Regions')
ax.set_xlabel('Start Date (Ordinal)')
ax.set_ylabel('Cold Rent per sqm (€)')
new_labels = [date.fromordinal(int(item)) for item in ax.get_xticks()]
ax.set_xticklabels(new_labels[:-2], rotation=45, fontsize=10)

# Creating custom legend for scatter plots and the 'All data' regression line
scatter_plots.append(line_all_data)
ax.legend(handles=scatter_plots, labels=selected_regions + ["All data"])

plt.tight_layout()
plt.show()
# Out:
# /var/folders/vx/5fczb1z530gfdp5n8z75tyy80000gn/T/ipykernel_4062/6834018.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels[:-2], rotation=45, fontsize=10)
